# %% [markdown]
# # Base de datos Pokemon : Mapas de calor y boxplots

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sb
import numpy as np; np.random.seed(0)
from matplotlib import cm

df = pd.read_csv('Pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# # Boxplots

# %% [markdown]
# *Boxplot Total*

# %%
sb.set_theme(style="whitegrid")
ax = sb.boxplot(x=df['Total'])

# %% [markdown]
# *Boxplot HP*

# %%
sb.set_theme(style="whitegrid")
ax = sb.boxplot(x=df['HP'])

# %% [markdown]
# *Boxplot Attack*

# %%
sb.set_theme(style="whitegrid")
ax = sb.boxplot(x=df['Attack'])

# %% [markdown]
# *Boxplot Defense*

# %%
sb.set_theme(style="whitegrid")
ax = sb.boxplot(x=df['Defense'])

# %% [markdown]
# *Boxplot Sp. Atk*

# %%
sb.set_theme(style="whitegrid")
ax = sb.boxplot(x=df['Sp. Atk'])

# %% [markdown]
# *Boxplot Sp. Def*

# %%
sb.set_theme(style="whitegrid")
ax = sb.boxplot(x=df['Sp. Def'])

# %% [markdown]
# *Boxplot Speed*

# %%
sb.set_theme(style="whitegrid")
ax = sb.boxplot(x=df['Speed'])

# %% [markdown]
# *Boxplot Generation*

# %%
sb.set_theme(style="whitegrid")
ax = sb.boxplot(x=df['Generation'])

# %% [markdown]
# # Mapa de Calor

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sb.heatmap(df.corr(), linewidths=0.1, vmax=1.0, square=True, 
           cmap=colormap, linecolor='white', annot=True);

# %% [markdown]
# # Histogramas

# %% [markdown]
# *Cantidad de Pokemon por tipo principal (tipo 1)*

# %%
df["Type 1"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# *Cantidad de Pokemon por tipo secundario (tipo 2)*

# %%
df["Type 2"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# *Cantidad de Pokemon por cada tipo (tipo 1 + tipo 2)*

# %%
type1Count = df['Type 1'].value_counts()
type2Count= df['Type 2'].value_counts()
typeTotal = type1Count + type2Count
typeTotal.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# *Número de Pokemon por cada generación*

# %%
df['Generation'].value_counts().plot.pie();

# %% [markdown]
# *Defensa con respecto al ataque*

# %%
plt.plot(df.Attack, df.Defense, '*')
plt.xlabel("Attack")
plt.ylabel("Defense")
plt.show()
